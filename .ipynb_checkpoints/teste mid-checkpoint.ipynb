# %% [markdown]
# Pode ser útil:
# https://mido.readthedocs.io/en/latest/installing.html e
# https://mido.readthedocs.io/en/latest/midi_files.html

# %% [markdown]
# Atributos:
# - velocity: how hard the note is hit
# - time :
#
#
# - mid.ticks_per_beat :o tamnho de um tick (é fixo para cada música)

# %% [markdown]
# You can use tick2second() and second2tick() to convert to and from seconds and ticks.
#
# Pygame uses the pygame.midi.

# %%
import mido
import time

# %%
msg = mido.Message('note_on', note=60)
msg.note
# Out:
# 60

# %% [markdown]
# Para abrir um arquivo .mid

# %%
from mido import MidiFile

mid = MidiFile('song.mid')

mid.length #total playback time in seconds
# Out:
# 157.3299999999979

# %%
mid.ticks_per_beat
# Out:
# 120

# %%
for i, track in enumerate(mid.tracks):
    print('Track {}: {}'.format(i, track.name))
    for msg in track:
        print(msg)
# Out:
# Track 0: untitled
# <meta message track_name name='untitled' time=0>
# <meta message time_signature numerator=4 denominator=4 clocks_per_click=24 notated_32nd_notes_per_beat=8 time=0>
# <meta message key_signature key='F' time=0>
# <meta message set_tempo tempo=400000 time=0>
# <meta message marker text='sequenced by: Don Carroll  donniec@ix.netcom.com' time=0>
# <meta message end_of_track time=0>
# Track 1: PIANO/LEFT
# <meta message midi_port port=0 time=0>
# <meta message track_name name='PIANO/LEFT' time=0>
# program_change channel=0 program=0 time=0
# control_change channel=0 control=7 value=120 time=0
# control_change channel=0 control=10 value=52 time=0
# control_change channel=0 control=64 value=0 time=0
# pitchwheel channel=0 pitch=0 time=0
# note_on channel=0 note=45 velocity=18 time=480
# note_on channel=0 note=45 velocity=0 time=19
# note_on channel=0 note=48 velocity=20 time=1
# note_on channel=0 note=48 velocity=0 time=19
# note_on channel=0 note=45 velocity=23 time=1
# ...

# %% [markdown]
# Para criar um arquivo .mid

# %%
from mido import Message, MidiFile, MidiTrack

mid = MidiFile()
track = MidiTrack()
mid.tracks.append(track)

track.append(Message('program_change', program=12, time=0))
track.append(Message('note_on', note=64, velocity=64, time=32))
track.append(Message('note_off', note=64, velocity=127, time=32))

mid.save('new_song.mid')

# %%
mid2 = MidiFile('new_song.mid')
for i, track in enumerate(mid2.tracks):
    print('Track {}: {}'.format(i, track.name))
    for msg in track:
        print(msg)
# Out:
# Track 0:
# program_change channel=0 program=12 time=0
# note_on channel=0 note=64 velocity=64 time=32
# note_off channel=0 note=64 velocity=127 time=32
# <meta message end_of_track time=0>

# %%
mid2.ticks_per_beat
# Out:
# 480
